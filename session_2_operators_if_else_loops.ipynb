# %% [markdown]
# # Operators in Python
#
# - Arithmetic Operators
# - Relational Operators
# - Logical Operators
# - Bitwise Operators
# - Assignment Operators
# - Membership Operators

# %%
# Arithmetric Operators
print(5+6)

print(5-6)

print(5*6)

print(5/2)

print(5//2)

print(5%2)

print(5**2)
# Out:
# 11
# -1
# 30
# 2.5
# 2
# 1
# 25

# %%
# Relational Operators
print(4>5)

print(4<5)

print(4>=4)

print(4<=4)

print(4==4)

print(4!=4)
# Out:
# False
# True
# True
# True
# True
# False

# %%
# Logical Operators
print(1 and 0)

print(1 or 0)

print(not 1)
# Out:
# 0
# 1
# False

# %%
# Bitwise Operators

# bitwise and
print(2 & 3)

# bitwise or
print(2 | 3)

# bitwise xor
print(2 ^ 3)

print(~3)

print(4 >> 2)

print(5 << 2)
# Out:
# 2
# 3
# 1
# -4
# 1
# 20

# %%
# Assignment Operators

# =
# a = 2

a = 2

# a = a % 2
a %= 2

# a++ ++a

print(a)
# Out:
# 0

# %%
# Membership Operators

# in/not in

print('D' not in 'Delhi')

print(1 in [2,3,4,5,6])
# Out:
# False
# False

# %%
# Program - Find the sum of a 3 digit number entered by the user

number = int(input('Enter a 3 digit number'))

# 345%10 -> 5
a = number%10

number = number//10

# 34%10 -> 4
b = number % 10

number = number//10
# 3 % 10 -> 3
c = number % 10

print(a + b + c)
# Out:
# Enter a 3 digit number123
# 6

# %% [markdown]
# # If-else in Python

# %%
# login program and indentation
# email -> nitish.campusx@gmail.com
# password -> 1234

email = input('enter email')
password = input('enter password')

if email == 'nitish.campusx@gmail.com' and password == '1234':
  print('Welcome')
elif email == 'nitish.campusx@gmail.com' and password != '1234':
  # tell the user
  print('Incorrect password')
  password = input('enter password again')
  if password == '1234':
    print('Welcome,finally!')
  else:
    print('beta tumse na ho paayega!')
else:
  print('Not correct')
# Out:
# enter emailnitish.campusx@gmail.com
# enter password123
# Incorrect password
# enter password again12
# beta tumse na ho paayega!

# %%
# if-else examples
# 1. Find the min of 3 given numbers
# 2. Menu Driven Program

# %%
# min of 3 number

a = int(input('first num'))
b = int(input('second num'))
c = int(input('third num'))

if a<b and a<c:
  print('smallest is',a)
elif b<c:
  print('smallest is',b)
else:
  print('smallest is',c)
# Out:
# first num2
# second num2
# third num3
# smallest is 2

# %%
# menu driven calculator
menu = input("""
Hi! how can I help you.
1. Enter 1 for pin change
2. Enter 2 for balance check
3. Enter 3 for withdrawl
4. Enter 4 for exit
""")

if menu == '1':
  print('pin change')
elif menu == '2':
  print('balance')
else:
  print('exit')
# Out:
# Hi! how can I help you.
# 1. Enter 1 for pin change
# 2. Enter 2 for balance check
# 3. Enter 3 for withdrawl
# 4. Enter 4 for exit
# 1
# pin change

# %% [markdown]
# # Modules in Python
#
# - math
# - keywords
# - random
# - datetime

# %%
# math
import math

math.sqrt(196)
# Out:
# 14.0

# %%
# keyword
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', '__peg_parser__', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# random
import random
print(random.randint(1,100))
# Out:
# 95

# %%
# datetime
import datetime
print(datetime.datetime.now())
# Out:
# 2024-01-28 10:55:40.152785

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
# C:\Users\Ansyl\Anaconda\lib\site-packages\IPython\kernel\__init__.py:12: ShimWarning: The `IPython.kernel` package has been deprecated since IPython 4.0.You should import from ipykernel or jupyter_client instead.
#   warn("The `IPython.kernel` package has been deprecated since IPython 4.0."
# WARNING: AstropyDeprecationWarning: The private astropy._erfa module has been made into its own package, pyerfa, which is a dependency of astropy and can be imported directly using "import erfa" [astropy._erfa]
# C:\Users\Ansyl\Anaconda\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# C:\Users\Ansyl\Anaconda\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,
# C:\Users\Ansyl\Anaconda\lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\notebook\utils.py:280: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   return LooseVersion(v) >= LooseVersion(check)
# C:\Users\Ansyl\Anaconda\lib\site-packages\notebook\utils.py:280: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   return LooseVersion(v) >= LooseVersion(check)
# C:\Users\Ansyl\Anaconda\lib\random.py:123: DeprecationWarning: Seeding based on hashing is deprecated
# since Python 3.9 and will be removed in a subsequent version. The only
# supported seed types are: None, int, float, str, bytes, and bytearray.
#   self.seed(x)
# C:\Users\Ansyl\Anaconda\lib\pkgutil.py:93: UserWarning: The numpy.array_api submodule is still experimental. See NEP 47.
#   __import__(info.name)
# C:\Users\Ansyl\Anaconda\lib\pkgutil.py:93: DeprecationWarning:
#
#   `numpy.distutils` is deprecated since NumPy 1.23.0, as a result
#   of the deprecation of `distutils` itself. It will be removed for
#   Python >= 3.12. For older Python versions it will remain present.
#   It is recommended to use `setuptools < 60.0` for those Python versions.
#   For more details, see:
#     https://numpy.org/devdocs/reference/distutils_status_migration.html
#
#
#   __import__(info.name)
# C:\Users\Ansyl\Anaconda\lib\site-packages\onedal\datatypes\validation.py:21: DeprecationWarning: Please use `spmatrix` from the `scipy.sparse` namespace, the `scipy.sparse.base` namespace is deprecated.
#   from scipy.sparse.base import spmatrix
# C:\Users\Ansyl\Anaconda\lib\site-packages\pandas\core\indexes\multi.py:626: DeprecationWarning: `cumproduct` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `cumprod` instead.
#   codes = cartesian_product(codes)
# C:\Users\Ansyl\Anaconda\lib\site-packages\pandas\core\reshape\util.py:54: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [tile_compat(np.repeat(x, b[i]), np.product(a[i])) for i, x in enumerate(X)]
# C:\Users\Ansyl\Anaconda\lib\site-packages\pandas\core\reshape\util.py:54: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [tile_compat(np.repeat(x, b[i]), np.product(a[i])) for i, x in enumerate(X)]
# C:\Users\Ansyl\Anaconda\lib\site-packages\pandas\core\indexes\multi.py:626: DeprecationWarning: `cumproduct` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `cumprod` instead.
#   codes = cartesian_product(codes)
# C:\Users\Ansyl\Anaconda\lib\site-packages\pandas\core\reshape\util.py:54: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [tile_compat(np.repeat(x, b[i]), np.product(a[i])) for i, x in enumerate(X)]
# C:\Users\Ansyl\Anaconda\lib\site-packages\pandas\core\reshape\util.py:54: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [tile_compat(np.repeat(x, b[i]), np.product(a[i])) for i, x in enumerate(X)]
# C:\Users\Ansyl\Anaconda\lib\site-packages\pandas\core\reshape\util.py:54: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [tile_compat(np.repeat(x, b[i]), np.product(a[i])) for i, x in enumerate(X)]
# C:\Users\Ansyl\Anaconda\lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# ...
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\pip\_vendor\packaging\version.py:111: DeprecationWarning: Creating a LegacyVersion has been deprecated and will be removed in the next major release
#   warnings.warn(
# C:\Users\Ansyl\Anaconda\lib\site-packages\scipy\stats\_distn_infrastructure.py:2167: DeprecationWarning:
#
# np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#
# C:\Users\Ansyl\Anaconda\lib\site-packages\scipy\stats\_distn_infrastructure.py:2084: DeprecationWarning:
#
# np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#
# C:\Users\Ansyl\Anaconda\lib\site-packages\rpy2\robjects\packages.py:367: UserWarning:
#
# The symbol 'quartz' is not in this R namespace/package.
#
# C:\Users\Ansyl\Anaconda\lib\site-packages\skimage\feature\_orb_descriptor_positions.py:8: DeprecationWarning:
#
# loadtxt(): Parsing an integer via a float is deprecated.  To avoid this warning, you can:
#     * make sure the original data is stored as integers.
#     * use the `converters=` keyword argument.  If you only use
#       NumPy 1.23 or later, `converters=float` will normally work.
#     * Use `np.loadtxt(...).astype(np.int64)` parsing the file as
#       floating point and then convert it.  (On all NumPy versions.)
#   (Deprecated NumPy 1.23)
#
# C:\Users\Ansyl\Anaconda\lib\site-packages\skimage\viewer\qt.py:5: MatplotlibDeprecationWarning:
#
#
# The QT_RC_MAJOR_VERSION attribute was deprecated in Matplotlib 3.5 and will be removed two minor releases later.
#
# No QCoreApplication instance found. Application patches not applied. You have to call load_stylesheet function after instantiation of QApplication to take effect.
# C:\Users\Ansyl\Anaconda\lib\site-packages\tensorboard\_vendor\html5lib\filters\sanitizer.py:29: DeprecationWarning:
#
# html5lib's sanitizer is deprecated; see https://github.com/html5lib/html5lib-python/issues/443 and please let us know if Bleach is unsuitable for your needs
# Cython              conda_content_trust mock                snowballstemmer
# IPython             conda_env           modulefinder        socket
# OpenSSL             conda_pack          mpmath              socketserver
# PIL                 conda_package_handling mprof               socks
# PyQt5               conda_token         msgpack             sockshandler
# TBB                 conda_verify        msilib              sortedcollections
# __future__          configparser        msvcrt              sortedcontainers
# _abc                constantly          multipledispatch    soupsieve
# _aix_support        contextlib          multiprocessing     sphinx
# _argon2_cffi_bindings contextvars         munkres             spyder
# _ast                cookiecutter        mypy_extensions     spyder_kernels
# _asyncio            copy                nacl                sqlalchemy
# _bisect             copyreg             navigator_updater   sqlite3
# _black_version      crypt               nbclassic           sre_compile
# _blake2             cryptography        nbclient            sre_constants
# _bootlocale         cssselect           nbconvert           sre_parse
# _bootsubprocess     csv                 nbformat            ssl
# _bz2                ctypes              nest_asyncio        sspi
# _cffi_backend       curl                netbios             sspicon
# _codecs             curses              netrc               stat
# _codecs_cn          cwp                 networkx            statistics
# _codecs_hk          cycler              nltk                statsmodels
# _codecs_iso2022     cython              nntplib             storemagic
# _codecs_jp          cythonmagic         nose                string
# _codecs_kr          cytoolz             notebook            stringprep
# _codecs_tw          daal4py             nt                  struct
# _collections        dask                ntpath              subprocess
# _collections_abc    dataclasses         ntsecuritycon       sunau
# _compat_pickle      datashader          nturl2path          symbol
# _compression        datashape           numba               sympy
# _contextvars        datetime            numbergen           sympyprinting
# _csv                dateutil            numbers             symtable
# _ctypes             dbi                 numexpr             sys
# _ctypes_test        dbm                 numpy               sysconfig
# _datetime           dde                 numpydoc            tables
# _decimal            debugpy             oauthlib            tabnanny
# _distutils_hack     decimal             odbc                tabulate
# _elementtree        decorator           olefile             tarfile
# _functools          deepdish            onedal              tbb
# _hashlib            defusedxml          opcode              tblib
# _heapq              diff_match_patch    openpyxl            telnetlib
# _imp                difflib             operator            tempfile
# _io                 dill                opt_einsum          tenacity
# _json               dis                 optparse            tensorboard
# _locale             distributed         os                  tensorboard_data_server
# _lsprof             distutils           packaging           tensorflow
# _lzma               doctest             pandas              tensorflow_estimator
# _markupbase         docutils            pandocfilters       tensorflow_io_gcs_filesystem
# _md5                email               panel               termcolor
# _msi                encodings           param               terminado
# _multibytecodec     ensurepip           paramiko            test
# _multiprocessing    entrypoints         parsel              test_pycosat
# _nsis               enum                parser              testpath
# _opcode             erfa                parso               tests
# _operator           errno               partd               text_unidecode
# _osx_support        et_xmlfile          past                textdistance
# _overlapped         fastjsonschema      pasta               textwrap
# _peg_parser         faulthandler        pathlib             this
# _pickle             ffmpeg              pathspec            threading
# _plotly_future_     filecmp             patsy               threadpoolctl
# _plotly_utils       fileinput           pdb                 three_merge
# _py_abc             filelock            pep8                tifffile
# _pydecimal          flake8              perfmon             time
# _pyio               flask               pexpect             timeit
# _pyrsistent_version flatbuffers         pickle              timer
# _pytest             fnmatch             pickleshare         tinycss
# _queue              fontTools           pickletools         tkinter
# _random             formatter           pip                 tldextract
# _rinterface_cffi_abi fractions           pipes               tlz
# _sha1               fsspec              pkg_resources       token
# _sha256             ftplib              pkginfo             tokenize
# _sha3               functools           pkgutil             toml
# _sha512             future              platform            tomli
# _signal             gast                platformdirs        tomlkit
# _sitebuiltins       gc                  plistlib            toolz
# _socket             genericpath         plotly              tornado
# _sqlite3            gensim              pluggy              tqdm
# _sre                getopt              pmdarima            trace
# _ssl                getpass             poplib              traceback
# _stat               gettext             posixpath           tracemalloc
# _statistics         glob                poyo                traitlets
# _string             glob2               pprint              tty
# _strptime           google_auth_oauthlib profile             turtle
# _struct             graphlib            prometheus_client   turtledemo
# _symtable           greenlet            prompt_toolkit      twisted
# _system_path        grpc                protego             types
# _testbuffer         gzip                pstats              typing
# _testcapi           h5py                psutil              typing_extensions
# _testconsole        hamcrest            pty                 tzdata
# _testimportmultiple hashlib             ptyprocess          tzlocal
# _testinternalcapi   heapdict            pvectorc            ujson
# _testmultiphase     heapq               py                  unicodedata
# _thread             hmac                py_compile          unidecode
# _threading_local    holoviews           pyasn1              unittest
# _tkinter            html                pyasn1_modules      urllib
# _tracemalloc        http                pyclbr              urllib3
# _uuid               hvplot              pycodestyle         uu
# _warnings           hyperlink           pycosat             uuid
# _weakref            idlelib             pycparser           venv
# _weakrefset         idna                pyct                w3lib
# _win32sysloader     imagecodecs         pycurl              warnings
# _winapi             imageio             pydispatch          watchdog
# _winxptheme         imagesize           pydoc               wave
# _xxsubinterpreters  imaplib             pydoc_data          wcwidth
# _yaml               imghdr              pydocstyle          weakref
# _zoneinfo           imp                 pyee                webbrowser
# abc                 importlib           pyexpat             webencodings
# absl                importlib_metadata  pyflakes            websocket
# adodbapi            incremental         pygments            websockets
# afxres              inflection          pylab               werkzeug
# aifc                iniconfig           pylint              wheel
# alabaster           inspect             pyls_spyder         widgetsnbextension
# anaconda_navigator  install             pylsp               win2kras
# anaconda_project    intake              pylsp_black         win32api
# antigravity         intervaltree        pylsp_jsonrpc       win32clipboard
# anyio               io                  pymer4              win32com
# appdirs             ipaddress           pyodbc              win32con
# argon2              ipykernel           pyparsing           win32console
# argparse            ipykernel_launcher  pyppeteer           win32cred
# array               ipython_genutils    pyrsistent          win32crypt
# arrow               ipywidgets          pytest              win32cryptcon
# ast                 isapi               pythoncom           win32ctypes
# astroid             isort               pytz                win32event
# astropy             isympy              pytz_deprecation_shim win32evtlog
# astunparse          itemadapter         pyviz_comms         win32evtlogutil
# asynchat            itemloaders         pywin               win32file
# asyncio             itertools           pywin32_bootstrap   win32gui
# asyncore            itsdangerous        pywin32_testutil    win32gui_struct
# atexit              jdcal               pywintypes          win32help
# atomicwrites        jedi                pywt                win32inet
# attr                jellyfish           pyximport           win32inetcon
# attrs               jinja2              qdarkstyle          win32job
# audioop             jinja2_time         qstylizer           win32lz
# automat             jmespath            qtawesome           win32net
# autopep8            joblib              qtconsole           win32netcon
# autoreload          json                qtpy                win32pdh
# babel               json5               queue               win32pdhquery
# backcall            jsonschema          queuelib            win32pdhutil
# backports           jupyter             quopri              win32pipe
# base64              jupyter_client      random              win32print
# bcrypt              jupyter_console     rasutil             win32process
# bdb                 jupyter_core        re                  win32profile
# binaryornot         jupyter_server      regcheck            win32ras
# binascii            jupyterlab          regex               win32rcparser
# binhex              jupyterlab_plotly   regutil             win32security
# binstar_client      jupyterlab_pygments repo_cli            win32service
# bisect              jupyterlab_server   reprlib             win32serviceutil
# bitarray            jupyterlab_widgets  requests            win32timezone
# bkcharts            jwt                 requests_file       win32trace
# black               keras               requests_oauthlib   win32traceutil
# blackd              kernprof            rlcompleter         win32transaction
# bleach              keyring             rmagic              win32ts
# blib2to3            keyword             rope                win32ui
# bokeh               kiwisolver          rpy2                win32uiole
# boto3               lazy_object_proxy   rsa                 win32verstamp
# botocore            lib2to3             rtree               win32wnet
# bottleneck          libarchive          ruamel_yaml         win_inet_pton
# brotli              libfuturize         run                 win_unicode_console
# bs4                 libpasteurize       runpy               wincertstore
# builtins            lief                s3transfer          winerror
# bz2                 line_profiler       sched               winioctlcon
# cProfile            linecache           scipy               winnt
# cachetools          llvmlite            scrapy              winperf
# calendar            locale              seaborn             winpty
# certifi             locket              secrets             winreg
# cffi                logging             select              winsound
# cgi                 lxml                selectors           winxpgui
# cgitb               lz4                 send2trash          winxptheme
# chardet             lzma                service_identity    wrapt
# charset_normalizer  mailbox             servicemanager      wsgiref
# chunk               mailcap             setuptools          xarray
# clang               markdown            shelve              xdrlib
# click               markupsafe          shlex               xlrd
# cloudpickle         marshal             shutil              xlsxwriter
# clyent              math                signal              xlwings
# cmath               matplotlib          sip                 xml
# cmd                 matplotlib_inline   sipconfig           xmlrpc
# code                mccabe              sipdistutils        xxsubtype
# codecs              memory_profiler     site                yaml
# codeop              menuinst            six                 yapf
# collections         mimetypes           skimage             yapftests
# colorama            mistune             sklearn             zict
# colorcet            mkl                 sklearnex           zipapp
# colorsys            mkl_fft             slugify             zipfile
# commctrl            mkl_random          smart_open          zipimport
# compileall          ml_dtypes           smtpd               zipp
# comtypes            mlxtend             smtplib             zlib
# concurrent          mmap                snappy              zmq
# conda               mmapfile            sndhdr              zoneinfo
# conda_build         mmsystem            sniffio             zope
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".
# C:\Users\Ansyl\Anaconda\lib\pkgutil.py:108: VisibleDeprecationWarning:
#
# zmq.eventloop.minitornado is deprecated in pyzmq 14.0 and will be removed.
#     Install tornado itself to use zmq with the tornado IOLoop.

# %% [markdown]
# # Loops in Python
#
# - Need for loops
# - While Loop
# - For Loop

# %%
# While loop example -> program to print the table
# Program -> Sum of all digits of a given number
# Program -> keep accepting numbers from users till he/she enters a 0 and then find the avg

# %%
number = int(input('enter the number'))

i = 1

while i<11:
  print(number,'*',i,'=',number * i)
  i += 1
# Out:
# enter the number3
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 3 * 7 = 21
# 3 * 8 = 24
# 3 * 9 = 27
# 3 * 10 = 30

# %%
# while loop with else

x = 1

while x < 3:
  print(x)
  x += 1

else:
  print('limit crossed')
# Out:
# 1
# 2
# limit crossed

# %%
# Guessing game

# generate a random integer between 1 and 100
import random
jackpot = random.randint(1,100)

guess = int(input('guess karo'))
counter = 1
while guess != jackpot:
  if guess < jackpot:
    print('galat!guess higher')
  else:
    print('galat!guess lower')

  guess = int(input('guess karo'))
  counter += 1

else:
  print('correct guess')
  print('attempts',counter)
# Out:
# guess karo50
# galat!guess lower
# guess karo25
# galat!guess lower
# guess karo12
# galat!guess lower
# guess karo6
# galat!guess lower
# guess karo3
# galat!guess lower
# guess karo2
# correct guess
# attempts 6

# %%
# For loop demo

for i in {1,2,3,4,5}:
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# For loop examples

# %% [markdown]
# ### Program - The current population of a town is 10000. The population of the town is increasing at the rate of 10% per year. You have to write a program to find out the population at the end of each of the last 10 years.

# %%
curr_pop = 10000

for i in range(10,0,-1):
  print(i,curr_pop)
  curr_pop = curr_pop - 0.1*curr_pop
# Out:
# 10 10000
# 9 9000.0
# 8 8100.0
# 7 7290.0
# 6 6561.0
# 5 5904.9
# 4 5314.41
# 3 4782.969
# 2 4304.6721
# 1 3874.20489

# %% [markdown]
# ### Sequence sum
#
# 1/1! + 2/2! + 3/3! + ...

# %%
# code here

# %%
# For loop vs While loops (When to use what?)

# %% [markdown]
# # Nested Loops

# %%
# Examples

# %%
# Program - Unique combination of 1,2,3,4
# Program - Pattern 1 and 2

# %% [markdown]
# ### Pattern 1
#
#
# *** <br>
# **** <br>
# ***<br>

# %%
for i in range(1, 4):
    print('*'*i)
# Out:
# *
# **
# ***

# %% [markdown]
# ### Pattern 2
#
# 1<br>
# 121<br>
# 12321<br>
# 1234321<br>

# %%
for i in range(1, 5):
    for j in range(1,i+1):
        print(j, end='')
    for k in range(i-1, 0, -1):
        print(k, end='')
    print()
# Out:
# 1
# 121
# 12321
# 1234321

# %% [markdown]
# # Loop Control Statement
#
# - Break
# - Continue
# - Pass

# %%
# Break demo

# %%
# Break example (Linear Search) -> Prime number in a given range

# %%
# Continue demo

# %%
# Continue Example (Ecommerce)

# %%
# Pass demo
